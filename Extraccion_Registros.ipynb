# %%
import win32com.client as win32ComClient

if __name__ == "__main__":
    try:
        dbName = "Ejemplo-Detalle de ventas.IMD"
        idea = win32ComClient.Dispatch(dispatch="Idea.IdeaClient")
        db = idea.OpenDatabase(dbName)
        task = db.TopRecordsExtraction()
        task.IncludeAllFields()
        task.AddKey("COD_PROD", "A")
        task.AddKey("TOTAL", "D")
        task.CreateVirtualDatabase=False
        task.criteria = ""
        resultdbName = "Extraccion_Reg_Sup_01.IMD"
        task.OutputFilename = (resultdbName)
        task.NumberofRecordsToExtract =5
        task.PerformTask()
    finally:
        task = None
        db = None
        idea = None
